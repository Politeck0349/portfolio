# %% [markdown]
# # NLP(Natural Language Processing)

# %% [markdown]
# # 크롤링한 데이터 파일을 이용한 한국어 분석

# %% [markdown]
# <span style="color: red; font-size: 18pt">
# 1. 한국어 분석에 필요한 모듈 임포트하기
# </span>

# %%
from konlpy.tag import *      
import pandas as pd

#konlpy.tag 에서 제공되는 함수 Okt(), Kkma( ) 호출 
okt = Okt() 
kkma = Kkma( )

# %% [markdown]
# <span style="color: red; font-size: 18pt">
# 2. 한국어 데이터셋에서 문장 추출하기
# </span>

# %% [markdown]
# <span style="color:blue; font-size: 14pt">
# 데이터셋 파일을 pandas를 활용하여 읽기  <b>(return type - DataFrame)
# </span>

# %% [markdown]
# <span style="color:#0000ff">
# ● pandas에서 제공하는 read_csv()함수, read_excel()함수는 데이터를 읽어서 DataFrame타입으로 리턴한다.
# </span>

# %%
file_path = "C:/Users/Mac001/LJH/music2.csv"
data_read = pd.read_csv(file_path, encoding='utf-8')  

#file_path = "c:/temp/자연어처리.xlsx"
#data_read = pd.read_excel(file_path)  

print(type(data_read))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data_read
# Out:
#                     노래제목                      가수명  \
# 0                 Kitsch                IVE (아이브)
# 1                  Ditto                 NewJeans
# 2                    OMG                 NewJeans
# 3               Hype boy                 NewJeans
# 4             Teddy Bear              STAYC(스테이씨)
# ..                   ...                      ...
# 95               딱 10CM만  10CM, BIG Naughty (서동현)
# 96            봄 사랑 벚꽃 말고         HIGH4 (하이포), 아이유
# 97  네가 보고 싶은 건 자연스러운 거겠지                      신예영
# 98     그댄 행복에 살텐데 (2022)                      최유리
# 99           Off My Face            Justin Bieber
#
#                               앨범제목
# 0                           Kitsch
# 1                   NewJeans 'OMG'
# 2                   NewJeans 'OMG'
# 3      NewJeans 1st EP 'New Jeans'
# 4                       Teddy Bear
# ..                             ...
# 95                         딱 10CM만
# 96                      봄 사랑 벚꽃 말고
# 97                          혼잣말 獨白
# 98               그댄 행복에 살텐데 (2022)
# 99  Justice (The Complete Edition)
#
# [100 rows x 3 columns]

# %%
data_title = data_read['가수명'].values  #제목 부분만 추출 

print('●  데이터 타입 : ', type(data_title))  #데이터 타입 numpy.ndarray
print('●  제목 개수 : ', len(data_title)) 
print('● ', data_title)
# Out:
# ●  데이터 타입 :  <class 'numpy.ndarray'>
# ●  제목 개수 :  100
# ●  ['IVE (아이브)' 'NewJeans' 'NewJeans' 'NewJeans' 'STAYC(스테이씨)' '우디 (Woody)'
#  '윤하 (YOUNHA)' '임영웅' '부석순 (SEVENTEEN)' 'Zior Park' 'DK(디셈버)' '지민'
#  'Charlie Puth' '임영웅' '지아' '포맨 (4MEN)' '임영웅' '임영웅' '임영웅' 'NewJeans' '임영웅'
#  '임영웅' 'j-hope, J. Cole' '임영웅' 'IVE (아이브)' '주주 시크릿' 'LE SSERAFIM (르세라핌)'
#  '임영웅' '임영웅' '지민' '임영웅' '임영웅' '임영웅' 'IVE (아이브)' '임영웅' 'imase' '태양' '멜로망스'
#  '송하예' 'Charlie Puth' 'WSG워너비 (가야G)' 'H1-KEY (하이키)' 'NCT DREAM' '방탄소년단'
#  '성시경' '방탄소년단' 'NMIXX' '지민' '정효빈' '(여자)아이들' '정국, 방탄소년단'
#  'BIG Naughty (서동현)' '테이' '방탄소년단' 'Charlie Puth' '지민' '우디 (Woody)' '#안녕'
#  '지코 (ZICO)' 'Anne-Marie, 민니 ((여자)아이들), (여자)아이들' '싸이 (PSY)' 'NewJeans'
#  '김민석 (멜로망스)' 'Sam Smith, Kim Petras' 'The Kid LAROI, Justin Bieber'
#  '방탄소년단' 'BLACKPINK' '김민석 (멜로망스)' '주호' 'WSG워너비 (가야G)' '(여자)아이들'
#  '먼데이 키즈 (Monday Kiz)' '10CM' 'STAYC(스테이씨)' '투모로우바이투게더' '김호중' '경서예지, 전건호'
#  'LE SSERAFIM (르세라핌)' 'IVE (아이브)' 'BLACKPINK' 'BIG Naughty (서동현)' 'Crush'
#  '이영지' '윤하 (YOUNHA)' '김호중, 송가인' '이홍기 (FT아일랜드)' '폴킴' '송하예' '임창정' 'NMIXX'
#  '신예영' '김호중' '주호' '경서' '방탄소년단' '10CM, BIG Naughty (서동현)'
#  'HIGH4 (하이포), 아이유' '신예영' '최유리' 'Justin Bieber']

# %%
num = 1
for i in data_title  :
    print('가수명', num, ')', i)
    num += 1
# Out:
# 가수명 1 ) IVE (아이브)
# 가수명 2 ) NewJeans
# 가수명 3 ) NewJeans
# 가수명 4 ) NewJeans
# 가수명 5 ) STAYC(스테이씨)
# 가수명 6 ) 우디 (Woody)
# 가수명 7 ) 윤하 (YOUNHA)
# 가수명 8 ) 임영웅
# 가수명 9 ) 부석순 (SEVENTEEN)
# 가수명 10 ) Zior Park
# 가수명 11 ) DK(디셈버)
# 가수명 12 ) 지민
# 가수명 13 ) Charlie Puth
# 가수명 14 ) 임영웅
# 가수명 15 ) 지아
# 가수명 16 ) 포맨 (4MEN)
# 가수명 17 ) 임영웅
# 가수명 18 ) 임영웅
# 가수명 19 ) 임영웅
# 가수명 20 ) NewJeans
# 가수명 21 ) 임영웅
# 가수명 22 ) 임영웅
# 가수명 23 ) j-hope, J. Cole
# 가수명 24 ) 임영웅
# 가수명 25 ) IVE (아이브)
# 가수명 26 ) 주주 시크릿
# 가수명 27 ) LE SSERAFIM (르세라핌)
# 가수명 28 ) 임영웅
# 가수명 29 ) 임영웅
# 가수명 30 ) 지민
# 가수명 31 ) 임영웅
# 가수명 32 ) 임영웅
# 가수명 33 ) 임영웅
# 가수명 34 ) IVE (아이브)
# 가수명 35 ) 임영웅
# 가수명 36 ) imase
# 가수명 37 ) 태양
# 가수명 38 ) 멜로망스
# 가수명 39 ) 송하예
# 가수명 40 ) Charlie Puth
# 가수명 41 ) WSG워너비 (가야G)
# 가수명 42 ) H1-KEY (하이키)
# 가수명 43 ) NCT DREAM
# 가수명 44 ) 방탄소년단
# 가수명 45 ) 성시경
# 가수명 46 ) 방탄소년단
# 가수명 47 ) NMIXX
# 가수명 48 ) 지민
# 가수명 49 ) 정효빈
# 가수명 50 ) (여자)아이들
# 가수명 51 ) 정국, 방탄소년단
# 가수명 52 ) BIG Naughty (서동현)
# 가수명 53 ) 테이
# 가수명 54 ) 방탄소년단
# 가수명 55 ) Charlie Puth
# 가수명 56 ) 지민
# 가수명 57 ) 우디 (Woody)
# 가수명 58 ) #안녕
# 가수명 59 ) 지코 (ZICO)
# 가수명 60 ) Anne-Marie, 민니 ((여자)아이들), (여자)아이들
# 가수명 61 ) 싸이 (PSY)
# 가수명 62 ) NewJeans
# 가수명 63 ) 김민석 (멜로망스)
# 가수명 64 ) Sam Smith, Kim Petras
# 가수명 65 ) The Kid LAROI, Justin Bieber
# 가수명 66 ) 방탄소년단
# 가수명 67 ) BLACKPINK
# 가수명 68 ) 김민석 (멜로망스)
# 가수명 69 ) 주호
# 가수명 70 ) WSG워너비 (가야G)
# 가수명 71 ) (여자)아이들
# 가수명 72 ) 먼데이 키즈 (Monday Kiz)
# 가수명 73 ) 10CM
# 가수명 74 ) STAYC(스테이씨)
# 가수명 75 ) 투모로우바이투게더
# 가수명 76 ) 김호중
# 가수명 77 ) 경서예지, 전건호
# 가수명 78 ) LE SSERAFIM (르세라핌)
# 가수명 79 ) IVE (아이브)
# 가수명 80 ) BLACKPINK
# 가수명 81 ) BIG Naughty (서동현)
# 가수명 82 ) Crush
# 가수명 83 ) 이영지
# 가수명 84 ) 윤하 (YOUNHA)
# 가수명 85 ) 김호중, 송가인
# 가수명 86 ) 이홍기 (FT아일랜드)
# 가수명 87 ) 폴킴
# 가수명 88 ) 송하예
# 가수명 89 ) 임창정
# 가수명 90 ) NMIXX
# 가수명 91 ) 신예영
# 가수명 92 ) 김호중
# 가수명 93 ) 주호
# 가수명 94 ) 경서
# 가수명 95 ) 방탄소년단
# 가수명 96 ) 10CM, BIG Naughty (서동현)
# 가수명 97 ) HIGH4 (하이포), 아이유
# 가수명 98 ) 신예영
# 가수명 99 ) 최유리
# 가수명 100 ) Justin Bieber

# %%
data_contents = data_read['노래제목'].values  #내용 부분만 추출 

print('●  데이터 타입 : ', type(data_contents))  #데이터 타입 numpy.ndarray
print('●  내용 개수 : ', len(data_contents))  
print('● ', data_contents )
# Out:
# ●  데이터 타입 :  <class 'numpy.ndarray'>
# ●  내용 개수 :  100
# ●  ['Kitsch' 'Ditto' 'OMG' 'Hype boy' 'Teddy Bear' 'Nostalgia' '사건의 지평선'
#  '사랑은 늘 도망가' '파이팅 해야지 (Feat. 이영지)' 'CHRISTIAN' '심(心)' 'Like Crazy'
#  "I Don't Think That I Like Her" '우리들의 블루스' '사랑하기 싫어' '나비무덤' '다시 만날 수 있을까'
#  'London Boy' 'Polaroid' 'Attention' '무지개' '이제 나만 믿어요'
#  'on the street (with J. Cole)' '아버지' 'After LIKE'
#  '밤이 무서워요 (Lonely Night)' 'ANTIFRAGILE' 'A bientot' '인생찬가'
#  'Set Me Free Pt.2' '손이 참 곱던 그대' '사랑해 진짜' '연애편지' 'LOVE DIVE' '보금자리'
#  'NIGHT DANCER' 'VIBE (feat. Jimin of BTS)' '사랑인가 봐' '너를 보는게 지친 하루에'
#  'Dangerously' '결국엔 너에게 닿아서' '건물 사이에 피어난 장미 (Rose Blossom)' 'Candy'
#  'Dynamite' '너의 모든 순간' '봄날' 'Love Me Like This' 'Face-off' '혼자가 아닌 나'
#  'Nxde'
#  'Dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack] (Feat. FIFA Sound)'
#  '사랑이라 믿었던 것들은 (Feat. 이수현)' 'Monologue' 'Butter' "That's Hilarious"
#  'Alone' 'Say I Love You' '해요 (2022)' '새삥 (Prod. ZICO) (Feat. 호미들)'
#  'Expectations' 'That That (prod. & feat. SUGA of BTS)' 'Cookie' '취중고백'
#  'Unholy' 'STAY' 'Permission to Dance' 'Shut Down' '너와 함께' '내가 아니라도'
#  '그때 그 순간 그대로 (그그그)' 'TOMBOY' '되돌리다' '그라데이션' 'Poppy (Korean Ver.)'
#  'Sugar Rush Ride' '그중에 그대를 만나' '다정히 내 이름을 부르면' 'FEARLESS' 'ELEVEN'
#  'Pink Venom' '정이라고 하자 (Feat. 10CM)' 'Rush Hour (Feat. j-hope of BTS)'
#  'NOT SORRY (Feat. pH-1) (Prod. by Slom)' '오르트구름' '당신을 만나' '아모르 파티'
#  '모든 날, 모든 순간 (Every day, Every Moment)' '그대를 알고' '그대라는 사치'
#  'Young, Dumb, Stupid' '마지막 사랑' '나의 목소리로' '잘가요' '나의 X에게' 'Yet To Come'
#  '딱 10CM만' '봄 사랑 벚꽃 말고' '네가 보고 싶은 건 자연스러운 거겠지' '그댄 행복에 살텐데 (2022)'
#  'Off My Face']

# %%
num = 1
for i in data_contents  :
    print('노래제목', num, ')', i)
    print('-'*50)
    num += 1
# Out:
# 노래제목 1 ) Kitsch
# --------------------------------------------------
# 노래제목 2 ) Ditto
# --------------------------------------------------
# 노래제목 3 ) OMG
# --------------------------------------------------
# 노래제목 4 ) Hype boy
# --------------------------------------------------
# 노래제목 5 ) Teddy Bear
# --------------------------------------------------
# 노래제목 6 ) Nostalgia
# --------------------------------------------------
# 노래제목 7 ) 사건의 지평선
# --------------------------------------------------
# 노래제목 8 ) 사랑은 늘 도망가
# --------------------------------------------------
# 노래제목 9 ) 파이팅 해야지 (Feat. 이영지)
# --------------------------------------------------
# 노래제목 10 ) CHRISTIAN
# --------------------------------------------------
# 노래제목 11 ) 심(心)
# --------------------------------------------------
# 노래제목 12 ) Like Crazy
# --------------------------------------------------
# 노래제목 13 ) I Don't Think That I Like Her
# --------------------------------------------------
# 노래제목 14 ) 우리들의 블루스
# --------------------------------------------------
# 노래제목 15 ) 사랑하기 싫어
# --------------------------------------------------
# 노래제목 16 ) 나비무덤
# --------------------------------------------------
# 노래제목 17 ) 다시 만날 수 있을까
# --------------------------------------------------
# 노래제목 18 ) London Boy
# --------------------------------------------------
# 노래제목 19 ) Polaroid
# --------------------------------------------------
# 노래제목 20 ) Attention
# --------------------------------------------------
# 노래제목 21 ) 무지개
# --------------------------------------------------
# 노래제목 22 ) 이제 나만 믿어요
# --------------------------------------------------
# 노래제목 23 ) on the street (with J. Cole)
# --------------------------------------------------
# 노래제목 24 ) 아버지
# --------------------------------------------------
# 노래제목 25 ) After LIKE
# --------------------------------------------------
# 노래제목 26 ) 밤이 무서워요 (Lonely Night)
# --------------------------------------------------
# 노래제목 27 ) ANTIFRAGILE
# --------------------------------------------------
# 노래제목 28 ) A bientot
# --------------------------------------------------
# 노래제목 29 ) 인생찬가
# --------------------------------------------------
# 노래제목 30 ) Set Me Free Pt.2
# --------------------------------------------------
# 노래제목 31 ) 손이 참 곱던 그대
# --------------------------------------------------
# 노래제목 32 ) 사랑해 진짜
# --------------------------------------------------
# 노래제목 33 ) 연애편지
# --------------------------------------------------
# 노래제목 34 ) LOVE DIVE
# --------------------------------------------------
# 노래제목 35 ) 보금자리
# --------------------------------------------------
# 노래제목 36 ) NIGHT DANCER
# --------------------------------------------------
# 노래제목 37 ) VIBE (feat. Jimin of BTS)
# --------------------------------------------------
# 노래제목 38 ) 사랑인가 봐
# --------------------------------------------------
# 노래제목 39 ) 너를 보는게 지친 하루에
# --------------------------------------------------
# 노래제목 40 ) Dangerously
# --------------------------------------------------
# 노래제목 41 ) 결국엔 너에게 닿아서
# --------------------------------------------------
# 노래제목 42 ) 건물 사이에 피어난 장미 (Rose Blossom)
# --------------------------------------------------
# 노래제목 43 ) Candy
# --------------------------------------------------
# 노래제목 44 ) Dynamite
# --------------------------------------------------
# 노래제목 45 ) 너의 모든 순간
# --------------------------------------------------
# 노래제목 46 ) 봄날
# --------------------------------------------------
# 노래제목 47 ) Love Me Like This
# --------------------------------------------------
# 노래제목 48 ) Face-off
# --------------------------------------------------
# 노래제목 49 ) 혼자가 아닌 나
# --------------------------------------------------
# 노래제목 50 ) Nxde
# --------------------------------------------------
# 노래제목 51 ) Dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack] (Feat. FIFA Sound)
# --------------------------------------------------
# 노래제목 52 ) 사랑이라 믿었던 것들은 (Feat. 이수현)
# --------------------------------------------------
# 노래제목 53 ) Monologue
# --------------------------------------------------
# 노래제목 54 ) Butter
# --------------------------------------------------
# 노래제목 55 ) That's Hilarious
# --------------------------------------------------
# 노래제목 56 ) Alone
# --------------------------------------------------
# 노래제목 57 ) Say I Love You
# --------------------------------------------------
# 노래제목 58 ) 해요 (2022)
# --------------------------------------------------
# 노래제목 59 ) 새삥 (Prod. ZICO) (Feat. 호미들)
# --------------------------------------------------
# 노래제목 60 ) Expectations
# --------------------------------------------------
# 노래제목 61 ) That That (prod. & feat. SUGA of BTS)
# --------------------------------------------------
# 노래제목 62 ) Cookie
# --------------------------------------------------
# 노래제목 63 ) 취중고백
# --------------------------------------------------
# 노래제목 64 ) Unholy
# --------------------------------------------------
# 노래제목 65 ) STAY
# --------------------------------------------------
# 노래제목 66 ) Permission to Dance
# --------------------------------------------------
# 노래제목 67 ) Shut Down
# --------------------------------------------------
# 노래제목 68 ) 너와 함께
# --------------------------------------------------
# 노래제목 69 ) 내가 아니라도
# --------------------------------------------------
# 노래제목 70 ) 그때 그 순간 그대로 (그그그)
# --------------------------------------------------
# 노래제목 71 ) TOMBOY
# --------------------------------------------------
# 노래제목 72 ) 되돌리다
# --------------------------------------------------
# 노래제목 73 ) 그라데이션
# --------------------------------------------------
# 노래제목 74 ) Poppy (Korean Ver.)
# --------------------------------------------------
# 노래제목 75 ) Sugar Rush Ride
# --------------------------------------------------
# 노래제목 76 ) 그중에 그대를 만나
# --------------------------------------------------
# 노래제목 77 ) 다정히 내 이름을 부르면
# --------------------------------------------------
# 노래제목 78 ) FEARLESS
# --------------------------------------------------
# 노래제목 79 ) ELEVEN
# --------------------------------------------------
# 노래제목 80 ) Pink Venom
# --------------------------------------------------
# 노래제목 81 ) 정이라고 하자 (Feat. 10CM)
# --------------------------------------------------
# 노래제목 82 ) Rush Hour (Feat. j-hope of BTS)
# --------------------------------------------------
# 노래제목 83 ) NOT SORRY (Feat. pH-1) (Prod. by Slom)
# --------------------------------------------------
# 노래제목 84 ) 오르트구름
# --------------------------------------------------
# 노래제목 85 ) 당신을 만나
# --------------------------------------------------
# 노래제목 86 ) 아모르 파티
# --------------------------------------------------
# 노래제목 87 ) 모든 날, 모든 순간 (Every day, Every Moment)
# --------------------------------------------------
# 노래제목 88 ) 그대를 알고
# --------------------------------------------------
# 노래제목 89 ) 그대라는 사치
# --------------------------------------------------
# 노래제목 90 ) Young, Dumb, Stupid
# --------------------------------------------------
# 노래제목 91 ) 마지막 사랑
# --------------------------------------------------
# 노래제목 92 ) 나의 목소리로
# --------------------------------------------------
# 노래제목 93 ) 잘가요
# --------------------------------------------------
# 노래제목 94 ) 나의 X에게
# --------------------------------------------------
# 노래제목 95 ) Yet To Come
# --------------------------------------------------
# 노래제목 96 ) 딱 10CM만
# --------------------------------------------------
# 노래제목 97 ) 봄 사랑 벚꽃 말고
# --------------------------------------------------
# 노래제목 98 ) 네가 보고 싶은 건 자연스러운 거겠지
# --------------------------------------------------
# 노래제목 99 ) 그댄 행복에 살텐데 (2022)
# --------------------------------------------------
# 노래제목 100 ) Off My Face
# --------------------------------------------------

# %%
data_tit_con = '■ 제목 : ' + data_title + ' ■ 내용 : ' + data_contents

# %%
data_tit_con
# Out:
# array(['■ 제목 : IVE (아이브) ■ 내용 : Kitsch', '■ 제목 : NewJeans ■ 내용 : Ditto',
#        '■ 제목 : NewJeans ■ 내용 : OMG', '■ 제목 : NewJeans ■ 내용 : Hype boy',
#        '■ 제목 : STAYC(스테이씨) ■ 내용 : Teddy Bear',
#        '■ 제목 : 우디 (Woody) ■ 내용 : Nostalgia',
#        '■ 제목 : 윤하 (YOUNHA) ■ 내용 : 사건의 지평선', '■ 제목 : 임영웅 ■ 내용 : 사랑은 늘 도망가',
#        '■ 제목 : 부석순 (SEVENTEEN) ■ 내용 : 파이팅 해야지 (Feat. 이영지)',
#        '■ 제목 : Zior Park ■ 내용 : CHRISTIAN', '■ 제목 : DK(디셈버) ■ 내용 : 심(心)',
#        '■ 제목 : 지민 ■ 내용 : Like Crazy',
#        "■ 제목 : Charlie Puth ■ 내용 : I Don't Think That I Like Her",
#        '■ 제목 : 임영웅 ■ 내용 : 우리들의 블루스', '■ 제목 : 지아 ■ 내용 : 사랑하기 싫어',
#        '■ 제목 : 포맨 (4MEN) ■ 내용 : 나비무덤', '■ 제목 : 임영웅 ■ 내용 : 다시 만날 수 있을까',
#        '■ 제목 : 임영웅 ■ 내용 : London Boy', '■ 제목 : 임영웅 ■ 내용 : Polaroid',
#        '■ 제목 : NewJeans ■ 내용 : Attention', '■ 제목 : 임영웅 ■ 내용 : 무지개',
#        '■ 제목 : 임영웅 ■ 내용 : 이제 나만 믿어요',
#        '■ 제목 : j-hope, J. Cole ■ 내용 : on the street (with J. Cole)',
#        '■ 제목 : 임영웅 ■ 내용 : 아버지', '■ 제목 : IVE (아이브) ■ 내용 : After LIKE',
#        '■ 제목 : 주주 시크릿 ■ 내용 : 밤이 무서워요 (Lonely Night)',
#        '■ 제목 : LE SSERAFIM (르세라핌) ■ 내용 : ANTIFRAGILE',
#        '■ 제목 : 임영웅 ■ 내용 : A bientot', '■ 제목 : 임영웅 ■ 내용 : 인생찬가',
#        '■ 제목 : 지민 ■ 내용 : Set Me Free Pt.2',
#        '■ 제목 : 임영웅 ■ 내용 : 손이 참 곱던 그대', '■ 제목 : 임영웅 ■ 내용 : 사랑해 진짜',
#        '■ 제목 : 임영웅 ■ 내용 : 연애편지', '■ 제목 : IVE (아이브) ■ 내용 : LOVE DIVE',
#        '■ 제목 : 임영웅 ■ 내용 : 보금자리', '■ 제목 : imase ■ 내용 : NIGHT DANCER',
#        '■ 제목 : 태양 ■ 내용 : VIBE (feat. Jimin of BTS)',
#        '■ 제목 : 멜로망스 ■ 내용 : 사랑인가 봐', '■ 제목 : 송하예 ■ 내용 : 너를 보는게 지친 하루에',
#        '■ 제목 : Charlie Puth ■ 내용 : Dangerously',
#        '■ 제목 : WSG워너비 (가야G) ■ 내용 : 결국엔 너에게 닿아서',
#        '■ 제목 : H1-KEY (하이키) ■ 내용 : 건물 사이에 피어난 장미 (Rose Blossom)',
#        '■ 제목 : NCT DREAM ■ 내용 : Candy', '■ 제목 : 방탄소년단 ■ 내용 : Dynamite',
#        '■ 제목 : 성시경 ■ 내용 : 너의 모든 순간', '■ 제목 : 방탄소년단 ■ 내용 : 봄날',
#        '■ 제목 : NMIXX ■ 내용 : Love Me Like This',
#        '■ 제목 : 지민 ■ 내용 : Face-off', '■ 제목 : 정효빈 ■ 내용 : 혼자가 아닌 나',
#        '■ 제목 : (여자)아이들 ■ 내용 : Nxde',
#        '■ 제목 : 정국, 방탄소년단 ■ 내용 : Dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack] (Feat. FIFA Sound)',
#        '■ 제목 : BIG Naughty (서동현) ■ 내용 : 사랑이라 믿었던 것들은 (Feat. 이수현)',
#        '■ 제목 : 테이 ■ 내용 : Monologue', '■ 제목 : 방탄소년단 ■ 내용 : Butter',
#        "■ 제목 : Charlie Puth ■ 내용 : That's Hilarious",
#        '■ 제목 : 지민 ■ 내용 : Alone',
#        '■ 제목 : 우디 (Woody) ■ 내용 : Say I Love You',
#        '■ 제목 : #안녕 ■ 내용 : 해요 (2022)',
#        '■ 제목 : 지코 (ZICO) ■ 내용 : 새삥 (Prod. ZICO) (Feat. 호미들)',
#        '■ 제목 : Anne-Marie, 민니 ((여자)아이들), (여자)아이들 ■ 내용 : Expectations',
#        '■ 제목 : 싸이 (PSY) ■ 내용 : That That (prod. & feat. SUGA of BTS)',
#        '■ 제목 : NewJeans ■ 내용 : Cookie', '■ 제목 : 김민석 (멜로망스) ■ 내용 : 취중고백',
#        '■ 제목 : Sam Smith, Kim Petras ■ 내용 : Unholy',
#        '■ 제목 : The Kid LAROI, Justin Bieber ■ 내용 : STAY',
#        '■ 제목 : 방탄소년단 ■ 내용 : Permission to Dance',
#        '■ 제목 : BLACKPINK ■ 내용 : Shut Down',
#        '■ 제목 : 김민석 (멜로망스) ■ 내용 : 너와 함께', '■ 제목 : 주호 ■ 내용 : 내가 아니라도',
#        '■ 제목 : WSG워너비 (가야G) ■ 내용 : 그때 그 순간 그대로 (그그그)',
#        '■ 제목 : (여자)아이들 ■ 내용 : TOMBOY',
#        '■ 제목 : 먼데이 키즈 (Monday Kiz) ■ 내용 : 되돌리다',
#        '■ 제목 : 10CM ■ 내용 : 그라데이션',
#        '■ 제목 : STAYC(스테이씨) ■ 내용 : Poppy (Korean Ver.)',
#        '■ 제목 : 투모로우바이투게더 ■ 내용 : Sugar Rush Ride',
#        '■ 제목 : 김호중 ■ 내용 : 그중에 그대를 만나',
#        '■ 제목 : 경서예지, 전건호 ■ 내용 : 다정히 내 이름을 부르면',
#        '■ 제목 : LE SSERAFIM (르세라핌) ■ 내용 : FEARLESS',
#        '■ 제목 : IVE (아이브) ■ 내용 : ELEVEN',
#        '■ 제목 : BLACKPINK ■ 내용 : Pink Venom',
#        '■ 제목 : BIG Naughty (서동현) ■ 내용 : 정이라고 하자 (Feat. 10CM)',
#        '■ 제목 : Crush ■ 내용 : Rush Hour (Feat. j-hope of BTS)',
#        '■ 제목 : 이영지 ■ 내용 : NOT SORRY (Feat. pH-1) (Prod. by Slom)',
#        '■ 제목 : 윤하 (YOUNHA) ■ 내용 : 오르트구름', '■ 제목 : 김호중, 송가인 ■ 내용 : 당신을 만나',
#        '■ 제목 : 이홍기 (FT아일랜드) ■ 내용 : 아모르 파티',
#        '■ 제목 : 폴킴 ■ 내용 : 모든 날, 모든 순간 (Every day, Every Moment)',
#        '■ 제목 : 송하예 ■ 내용 : 그대를 알고', '■ 제목 : 임창정 ■ 내용 : 그대라는 사치',
#        '■ 제목 : NMIXX ■ 내용 : Young, Dumb, Stupid',
#        '■ 제목 : 신예영 ■ 내용 : 마지막 사랑', '■ 제목 : 김호중 ■ 내용 : 나의 목소리로',
#        '■ 제목 : 주호 ■ 내용 : 잘가요', '■ 제목 : 경서 ■ 내용 : 나의 X에게',
#        '■ 제목 : 방탄소년단 ■ 내용 : Yet To Come',
#        '■ 제목 : 10CM, BIG Naughty (서동현) ■ 내용 : 딱 10CM만',
#        '■ 제목 : HIGH4 (하이포), 아이유 ■ 내용 : 봄 사랑 벚꽃 말고',
#        '■ 제목 : 신예영 ■ 내용 : 네가 보고 싶은 건 자연스러운 거겠지',
#        '■ 제목 : 최유리 ■ 내용 : 그댄 행복에 살텐데 (2022)',
#        '■ 제목 : Justin Bieber ■ 내용 : Off My Face'], dtype=object)

# %%
#제목과 내용 
print('● 데이터 타입 : ', type(data_tit_con))
print('● shape : ', data_tit_con.shape)  #1차원 리스트 개념 
print('● 데이터 개수 : ',len(data_tit_con))
# Out:
# ● 데이터 타입 :  <class 'numpy.ndarray'>
# ● shape :  (100,)
# ● 데이터 개수 :  100

# %%
num = 1

for i in data_tit_con :
    print('제목과 내용', num, ')', i)
    print(type(i))
    print('-'*50)
    num += 1
# Out:
# 제목과 내용 1 ) ■ 제목 : IVE (아이브) ■ 내용 : Kitsch
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 2 ) ■ 제목 : NewJeans ■ 내용 : Ditto
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 3 ) ■ 제목 : NewJeans ■ 내용 : OMG
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 4 ) ■ 제목 : NewJeans ■ 내용 : Hype boy
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 5 ) ■ 제목 : STAYC(스테이씨) ■ 내용 : Teddy Bear
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 6 ) ■ 제목 : 우디 (Woody) ■ 내용 : Nostalgia
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 7 ) ■ 제목 : 윤하 (YOUNHA) ■ 내용 : 사건의 지평선
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 8 ) ■ 제목 : 임영웅 ■ 내용 : 사랑은 늘 도망가
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 9 ) ■ 제목 : 부석순 (SEVENTEEN) ■ 내용 : 파이팅 해야지 (Feat. 이영지)
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 10 ) ■ 제목 : Zior Park ■ 내용 : CHRISTIAN
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 11 ) ■ 제목 : DK(디셈버) ■ 내용 : 심(心)
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 12 ) ■ 제목 : 지민 ■ 내용 : Like Crazy
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 13 ) ■ 제목 : Charlie Puth ■ 내용 : I Don't Think That I Like Her
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 14 ) ■ 제목 : 임영웅 ■ 내용 : 우리들의 블루스
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 15 ) ■ 제목 : 지아 ■ 내용 : 사랑하기 싫어
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 16 ) ■ 제목 : 포맨 (4MEN) ■ 내용 : 나비무덤
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 17 ) ■ 제목 : 임영웅 ■ 내용 : 다시 만날 수 있을까
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 18 ) ■ 제목 : 임영웅 ■ 내용 : London Boy
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 19 ) ■ 제목 : 임영웅 ■ 내용 : Polaroid
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 20 ) ■ 제목 : NewJeans ■ 내용 : Attention
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 21 ) ■ 제목 : 임영웅 ■ 내용 : 무지개
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 22 ) ■ 제목 : 임영웅 ■ 내용 : 이제 나만 믿어요
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 23 ) ■ 제목 : j-hope, J. Cole ■ 내용 : on the street (with J. Cole)
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 24 ) ■ 제목 : 임영웅 ■ 내용 : 아버지
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 25 ) ■ 제목 : IVE (아이브) ■ 내용 : After LIKE
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 26 ) ■ 제목 : 주주 시크릿 ■ 내용 : 밤이 무서워요 (Lonely Night)
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 27 ) ■ 제목 : LE SSERAFIM (르세라핌) ■ 내용 : ANTIFRAGILE
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 28 ) ■ 제목 : 임영웅 ■ 내용 : A bientot
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 29 ) ■ 제목 : 임영웅 ■ 내용 : 인생찬가
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 30 ) ■ 제목 : 지민 ■ 내용 : Set Me Free Pt.2
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 31 ) ■ 제목 : 임영웅 ■ 내용 : 손이 참 곱던 그대
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 32 ) ■ 제목 : 임영웅 ■ 내용 : 사랑해 진짜
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 33 ) ■ 제목 : 임영웅 ■ 내용 : 연애편지
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 34 ) ■ 제목 : IVE (아이브) ■ 내용 : LOVE DIVE
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 35 ) ■ 제목 : 임영웅 ■ 내용 : 보금자리
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 36 ) ■ 제목 : imase ■ 내용 : NIGHT DANCER
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 37 ) ■ 제목 : 태양 ■ 내용 : VIBE (feat. Jimin of BTS)
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 38 ) ■ 제목 : 멜로망스 ■ 내용 : 사랑인가 봐
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 39 ) ■ 제목 : 송하예 ■ 내용 : 너를 보는게 지친 하루에
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 40 ) ■ 제목 : Charlie Puth ■ 내용 : Dangerously
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 41 ) ■ 제목 : WSG워너비 (가야G) ■ 내용 : 결국엔 너에게 닿아서
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 42 ) ■ 제목 : H1-KEY (하이키) ■ 내용 : 건물 사이에 피어난 장미 (Rose Blossom)
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 43 ) ■ 제목 : NCT DREAM ■ 내용 : Candy
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 44 ) ■ 제목 : 방탄소년단 ■ 내용 : Dynamite
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 45 ) ■ 제목 : 성시경 ■ 내용 : 너의 모든 순간
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 46 ) ■ 제목 : 방탄소년단 ■ 내용 : 봄날
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 47 ) ■ 제목 : NMIXX ■ 내용 : Love Me Like This
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 48 ) ■ 제목 : 지민 ■ 내용 : Face-off
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 49 ) ■ 제목 : 정효빈 ■ 내용 : 혼자가 아닌 나
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 50 ) ■ 제목 : (여자)아이들 ■ 내용 : Nxde
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 51 ) ■ 제목 : 정국, 방탄소년단 ■ 내용 : Dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack] (Feat. FIFA Sound)
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 52 ) ■ 제목 : BIG Naughty (서동현) ■ 내용 : 사랑이라 믿었던 것들은 (Feat. 이수현)
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 53 ) ■ 제목 : 테이 ■ 내용 : Monologue
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 54 ) ■ 제목 : 방탄소년단 ■ 내용 : Butter
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 55 ) ■ 제목 : Charlie Puth ■ 내용 : That's Hilarious
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 56 ) ■ 제목 : 지민 ■ 내용 : Alone
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 57 ) ■ 제목 : 우디 (Woody) ■ 내용 : Say I Love You
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 58 ) ■ 제목 : #안녕 ■ 내용 : 해요 (2022)
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 59 ) ■ 제목 : 지코 (ZICO) ■ 내용 : 새삥 (Prod. ZICO) (Feat. 호미들)
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 60 ) ■ 제목 : Anne-Marie, 민니 ((여자)아이들), (여자)아이들 ■ 내용 : Expectations
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 61 ) ■ 제목 : 싸이 (PSY) ■ 내용 : That That (prod. & feat. SUGA of BTS)
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 62 ) ■ 제목 : NewJeans ■ 내용 : Cookie
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 63 ) ■ 제목 : 김민석 (멜로망스) ■ 내용 : 취중고백
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 64 ) ■ 제목 : Sam Smith, Kim Petras ■ 내용 : Unholy
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 65 ) ■ 제목 : The Kid LAROI, Justin Bieber ■ 내용 : STAY
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 66 ) ■ 제목 : 방탄소년단 ■ 내용 : Permission to Dance
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 67 ) ■ 제목 : BLACKPINK ■ 내용 : Shut Down
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 68 ) ■ 제목 : 김민석 (멜로망스) ■ 내용 : 너와 함께
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 69 ) ■ 제목 : 주호 ■ 내용 : 내가 아니라도
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 70 ) ■ 제목 : WSG워너비 (가야G) ■ 내용 : 그때 그 순간 그대로 (그그그)
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 71 ) ■ 제목 : (여자)아이들 ■ 내용 : TOMBOY
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 72 ) ■ 제목 : 먼데이 키즈 (Monday Kiz) ■ 내용 : 되돌리다
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 73 ) ■ 제목 : 10CM ■ 내용 : 그라데이션
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 74 ) ■ 제목 : STAYC(스테이씨) ■ 내용 : Poppy (Korean Ver.)
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 75 ) ■ 제목 : 투모로우바이투게더 ■ 내용 : Sugar Rush Ride
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 76 ) ■ 제목 : 김호중 ■ 내용 : 그중에 그대를 만나
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 77 ) ■ 제목 : 경서예지, 전건호 ■ 내용 : 다정히 내 이름을 부르면
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 78 ) ■ 제목 : LE SSERAFIM (르세라핌) ■ 내용 : FEARLESS
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 79 ) ■ 제목 : IVE (아이브) ■ 내용 : ELEVEN
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 80 ) ■ 제목 : BLACKPINK ■ 내용 : Pink Venom
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 81 ) ■ 제목 : BIG Naughty (서동현) ■ 내용 : 정이라고 하자 (Feat. 10CM)
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 82 ) ■ 제목 : Crush ■ 내용 : Rush Hour (Feat. j-hope of BTS)
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 83 ) ■ 제목 : 이영지 ■ 내용 : NOT SORRY (Feat. pH-1) (Prod. by Slom)
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 84 ) ■ 제목 : 윤하 (YOUNHA) ■ 내용 : 오르트구름
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 85 ) ■ 제목 : 김호중, 송가인 ■ 내용 : 당신을 만나
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 86 ) ■ 제목 : 이홍기 (FT아일랜드) ■ 내용 : 아모르 파티
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 87 ) ■ 제목 : 폴킴 ■ 내용 : 모든 날, 모든 순간 (Every day, Every Moment)
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 88 ) ■ 제목 : 송하예 ■ 내용 : 그대를 알고
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 89 ) ■ 제목 : 임창정 ■ 내용 : 그대라는 사치
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 90 ) ■ 제목 : NMIXX ■ 내용 : Young, Dumb, Stupid
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 91 ) ■ 제목 : 신예영 ■ 내용 : 마지막 사랑
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 92 ) ■ 제목 : 김호중 ■ 내용 : 나의 목소리로
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 93 ) ■ 제목 : 주호 ■ 내용 : 잘가요
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 94 ) ■ 제목 : 경서 ■ 내용 : 나의 X에게
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 95 ) ■ 제목 : 방탄소년단 ■ 내용 : Yet To Come
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 96 ) ■ 제목 : 10CM, BIG Naughty (서동현) ■ 내용 : 딱 10CM만
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 97 ) ■ 제목 : HIGH4 (하이포), 아이유 ■ 내용 : 봄 사랑 벚꽃 말고
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 98 ) ■ 제목 : 신예영 ■ 내용 : 네가 보고 싶은 건 자연스러운 거겠지
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 99 ) ■ 제목 : 최유리 ■ 내용 : 그댄 행복에 살텐데 (2022)
# <class 'str'>
# --------------------------------------------------
# 제목과 내용 100 ) ■ 제목 : Justin Bieber ■ 내용 : Off My Face
# <class 'str'>
# --------------------------------------------------

# %% [markdown]
# <span style="color: red; font-size: 18pt">
# 3. 문장에서 [(형태소, 품사)] 및 명사 추출하기
# </span>

# %% [markdown]
# <span style="color: magenta ; font-size: 18pt">
# ● Okt() 활용한 한국어 분석
# </span>

# %% [markdown]
# <span style="color: red ; font-size: 14pt">
# 3.1. pos() 함수를 이용한 [(형태소, 품사)] 추출하기
# </span>

# %%
okt_pos=[]  #형태소와 품사 부분 저장을 위한 리스트

for data in data_tit_con : 
    #형태소와 품사 부분 리스트에 추가 
    #okt.pos()는 리스트 안에 (튜플)을 넣어서 리턴
    #okt_pos는 리스트이고,okt.pos() 결과도 리스트이므로 2차원리스트 생성 
    
    okt_pos.append(okt.pos(data))

# %%
#바깥쪽 리스트 안에 또 하나의 리스트가 포함되어 있으며
#내부 리스트 안에 튜플이 있는 구조

print(okt_pos)
# Out:
# [[('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('IVE', 'Alpha'), ('(', 'Punctuation'), ('아이브', 'Noun'), (')', 'Punctuation'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('Kitsch', 'Alpha')], [('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('NewJeans', 'Alpha'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('Ditto', 'Alpha')], [('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('NewJeans', 'Alpha'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('OMG', 'Alpha')], [('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('NewJeans', 'Alpha'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('Hype', 'Alpha'), ('boy', 'Alpha')], [('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('STAYC', 'Alpha'), ('(', 'Punctuation'), ('스테이', 'Noun'), ('씨', 'Suffix'), (')', 'Punctuation'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('Teddy', 'Alpha'), ('Bear', 'Alpha')], [('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('우디', 'Noun'), ('(', 'Punctuation'), ('Woody', 'Alpha'), (')', 'Punctuation'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('Nostalgia', 'Alpha')], [('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('윤하', 'Noun'), ('(', 'Punctuation'), ('YOUNHA', 'Alpha'), (')', 'Punctuation'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('사건', 'Noun'), ('의', 'Josa'), ('지평선', 'Noun')], [('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('임영웅', 'Noun'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('사랑', 'Noun'), ('은', 'Josa'), ('늘', 'Noun'), ('도망가', 'Verb')], [('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('부석', 'Noun'), ('순', 'Noun'), ('(', 'Punctuation'), ('SEVENTEEN', 'Alpha'), (')', 'Punctuation'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('파이팅', 'Noun'), ('해야지', 'Verb'), ('(', 'Punctuation'), ('Feat', 'Alpha'), ('.', 'Punctuation'), ('이영지', 'Noun'), (')', 'Punctuation')], [('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('Zior', 'Alpha'), ('Park', 'Alpha'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('CHRISTIAN', 'Alpha')], [('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('DK', 'Alpha'), ('(', 'Punctuation'), ('디셈버', 'Noun'), (')', 'Punctuation'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('심', 'Noun'), ('(', 'Punctuation'), ('心', 'Foreign'), (')', 'Punctuation')], [('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('지민', 'Noun'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('Like', 'Alpha'), ('Crazy', 'Alpha')], [('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('Charlie', 'Alpha'), ('Puth', 'Alpha'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('I', 'Alpha'), ('Don', 'Alpha'), ("'", 'Punctuation'), ('t', 'Alpha'), ('Think', 'Alpha'), ('That', 'Alpha'), ('I', 'Alpha'), ('Like', 'Alpha'), ('Her', 'Alpha')], [('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('임영웅', 'Noun'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('우리', 'Noun'), ('들', 'Suffix'), ('의', 'Josa'), ('블루스', 'Noun')], [('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('지아', 'Noun'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('사랑', 'Noun'), ('하기', 'Verb'), ('싫어', 'Adjective')], [('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('포맨', 'Noun'), ('(', 'Punctuation'), ('4', 'Number'), ('MEN', 'Alpha'), (')', 'Punctuation'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('나비', 'Noun'), ('무덤', 'Noun')], [('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('임영웅', 'Noun'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('다시', 'Noun'), ('만날', 'Noun'), ('수', 'Noun'), ('있을까', 'Adjective')], [('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('임영웅', 'Noun'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('London', 'Alpha'), ('Boy', 'Alpha')], [('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('임영웅', 'Noun'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctu ...

# %%
import numpy as np
print('● 데이터 타입 : ', type(okt_pos)) 
print("● [(형태소, 품사), ...(형태소, 품사)] 리스트 개수 : ", len(okt_pos) )
# Out:
# ● 데이터 타입 :  <class 'list'>
# ● [(형태소, 품사), ...(형태소, 품사)] 리스트 개수 :  100

# %%
okt_pos
# Out:
# [[('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('IVE', 'Alpha'),
#   ('(', 'Punctuation'),
#   ('아이브', 'Noun'),
#   (')', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('Kitsch', 'Alpha')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('NewJeans', 'Alpha'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('Ditto', 'Alpha')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('NewJeans', 'Alpha'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('OMG', 'Alpha')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('NewJeans', 'Alpha'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('Hype', 'Alpha'),
#   ('boy', 'Alpha')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('STAYC', 'Alpha'),
#   ('(', 'Punctuation'),
#   ('스테이', 'Noun'),
#   ('씨', 'Suffix'),
#   (')', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('Teddy', 'Alpha'),
#   ('Bear', 'Alpha')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('우디', 'Noun'),
#   ('(', 'Punctuation'),
#   ('Woody', 'Alpha'),
#   (')', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('Nostalgia', 'Alpha')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('윤하', 'Noun'),
#   ('(', 'Punctuation'),
#   ('YOUNHA', 'Alpha'),
#   (')', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('사건', 'Noun'),
#   ('의', 'Josa'),
#   ('지평선', 'Noun')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('임영웅', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('사랑', 'Noun'),
#   ('은', 'Josa'),
#   ('늘', 'Noun'),
#   ('도망가', 'Verb')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('부석', 'Noun'),
#   ('순', 'Noun'),
#   ('(', 'Punctuation'),
#   ('SEVENTEEN', 'Alpha'),
#   (')', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('파이팅', 'Noun'),
#   ('해야지', 'Verb'),
#   ('(', 'Punctuation'),
#   ('Feat', 'Alpha'),
#   ('.', 'Punctuation'),
#   ('이영지', 'Noun'),
#   (')', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('Zior', 'Alpha'),
#   ('Park', 'Alpha'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('CHRISTIAN', 'Alpha')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('DK', 'Alpha'),
#   ('(', 'Punctuation'),
#   ('디셈버', 'Noun'),
#   (')', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('심', 'Noun'),
#   ('(', 'Punctuation'),
#   ('心', 'Foreign'),
#   (')', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('지민', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('Like', 'Alpha'),
#   ('Crazy', 'Alpha')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('Charlie', 'Alpha'),
#   ('Puth', 'Alpha'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('I', 'Alpha'),
#   ('Don', 'Alpha'),
#   ("'", 'Punctuation'),
#   ('t', 'Alpha'),
#   ('Think', 'Alpha'),
#   ('That', 'Alpha'),
#   ('I', 'Alpha'),
#   ('Like', 'Alpha'),
#   ('Her', 'Alpha')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('임영웅', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('우리', 'Noun'),
#   ('들', 'Suffix'),
#   ('의', 'Josa'),
#   ('블루스', 'Noun')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('지아', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('사랑', 'Noun'),
#   ('하기', 'Verb'),
#   ('싫어', 'Adjective')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('포맨', 'Noun'),
#   ('(', 'Punctuation'),
#   ('4', 'Number'),
#   ('MEN', 'Alpha'),
#   (')', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('나비', 'Noun'),
#   ('무덤', 'Noun')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('임영웅', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('다시', 'Noun'),
#   ('만날', 'Noun'),
#   ('수', 'Noun'),
#   ('있을까', 'Adjective')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('임영웅', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('London', 'Alpha'),
#   ('Boy', 'Alpha')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('임영웅', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('Polaroid', 'Alpha')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('NewJeans', 'Alpha'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('Attention', 'Alpha')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('임영웅', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('무지개', 'Noun')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('임영웅', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('이제', 'Noun'),
#   ('나', 'Noun'),
#   ('만', 'Josa'),
#   ('믿어요', 'Verb')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('j', 'Alpha'),
#   ('-', 'Punctuation'),
#   ('hope', 'Alpha'),
#   (',', 'Punctuation'),
#   ('J', 'Alpha'),
#   ('.', 'Punctuation'),
#   ('Cole', 'Alpha'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('on', 'Alpha'),
#   ('the', 'Alpha'),
#   ('street', 'Alpha'),
#   ('(', 'Punctuation'),
#   ('with', 'Alpha'),
#   ('J', 'Alpha'),
#   ('.', 'Punctuation'),
#   ('Cole', 'Alpha'),
#   (')', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('임영웅', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('아버지', 'Noun')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('IVE', 'Alpha'),
#   ('(', 'Punctuation'),
#   ('아이브', 'Noun'),
#   (')', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('After', 'Alpha'),
#   ('LIKE', 'Alpha')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('주주', 'Noun'),
#   ('시크릿', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('밤', 'Noun'),
#   ('이', 'Josa'),
#   ('무서워요', 'Adjective'),
#   ('(', 'Punctuation'),
#   ('Lonely', 'Alpha'),
#   ('Night', 'Alpha'),
#   (')', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('LE', 'Alpha'),
#   ('SSERAFIM', 'Alpha'),
#   ('(', 'Punctuation'),
#   ('르', 'Noun'),
#   ('세라핌', 'Noun'),
#   (')', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('ANTIFRAGILE', 'Alpha')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('임영웅', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('A', 'Alpha'),
#   ('bientot', 'Alpha')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('임영웅', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('인생', 'Noun'),
#   ('찬가', 'Noun')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('지민', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('Set', 'Alpha'),
#   ('Me', 'Alpha'),
#   ('Free', 'Alpha'),
#   ('Pt', 'Alpha'),
#   ('.', 'Punctuation'),
#   ('2', 'Number')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('임영웅', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('손', 'Noun'),
#   ('이', 'Josa'),
#   ('참', 'Verb'),
#   ('곱던', 'Adjective'),
#   ('그대', 'Noun')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('임영웅', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('사랑', 'Noun'),
#   ('해', 'Verb'),
#   ('진짜', 'Noun')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('임영웅', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('연애편지', 'Noun')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('IVE', 'Alpha'),
#   ('(', 'Punctuation'),
#   ('아이브', 'Noun'),
#   (')', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('LOVE', 'Alpha'),
#   ('DIVE', 'Alpha')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('임영웅', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('보금자리', 'Noun')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('imase', 'Alpha'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('NIGHT', 'Alpha'),
#   ('DANCER', 'Alpha')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('태양', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('VIBE', 'Alpha'),
#   ('(', 'Punctuation'),
#   ('feat', 'Alpha'),
#   ('.', 'Punctuation'),
#   ('Jimin', 'Alpha'),
#   ('of', 'Alpha'),
#   ('BTS', 'Alpha'),
#   (')', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('멜', 'Verb'),
#   ('로망스', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('사랑', 'Noun'),
#   ('인가', 'Josa'),
#   ('봐', 'Verb')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('송하예', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('너', 'Noun'),
#   ('를', 'Josa'),
#   ('보는게', 'Verb'),
#   ('지친', 'Verb'),
#   ('하루', 'Noun'),
#   ('에', 'Josa')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('Charlie', 'Alpha'),
#   ('Puth', 'Alpha'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('Dangerously', 'Alpha')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('WSG', 'Alpha'),
#   ('워', 'Noun'),
#   ('너비', 'Noun'),
#   ('(', 'Punctuation'),
#   ('가야', 'Noun'),
#   ('G', 'Alpha'),
#   (')', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('결국', 'Adverb'),
#   ('엔', 'Josa'),
#   ('너', 'Noun'),
#   ('에게', 'Josa'),
#   ('닿아서', 'Verb')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('H', 'Alpha'),
#   ('1', 'Number'),
#   ('-', 'Punctuation'),
#   ('KEY', 'Alpha'),
#   ('(', 'Punctuation'),
#   ('하이', 'Noun'),
#   ('키', 'Noun'),
#   (')', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('건물', 'Noun'),
#   ('사이', 'Noun'),
#   ('에', 'Josa'),
#   ('피어', 'Noun'),
#   ('난', 'Josa'),
#   ('장미', 'Noun'),
#   ('(', 'Punctuation'),
#   ('Rose', 'Alpha'),
#   ('Blossom', 'Alpha'),
#   (')', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('NCT', 'Alpha'),
#   ('DREAM', 'Alpha'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('Candy', 'Alpha')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('방탄소년단', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('Dynamite', 'Alpha')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('성시경', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('너', 'Noun'),
#   ('의', 'Josa'),
#   ('모든', 'Noun'),
#   ('순간', 'Noun')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('방탄소년단', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('봄날', 'Noun')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('NMIXX', 'Alpha'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('Love', 'Alpha'),
#   ('Me', 'Alpha'),
#   ('Like', 'Alpha'),
#   ('This', 'Alpha')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('지민', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('Face', 'Alpha'),
#   ('-', 'Punctuation'),
#   ('off', 'Alpha')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('정', 'Noun'),
#   ('효빈', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('혼자', 'Noun'),
#   ('가', 'Josa'),
#   ('아닌', 'Adjective'),
#   ('나', 'Noun')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('(', 'Punctuation'),
#   ('여자', 'Noun'),
#   (')', 'Punctuation'),
#   ('아이', 'Noun'),
#   ('들', 'Suffix'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('Nxde', 'Alpha')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('정국', 'Noun'),
#   (',', 'Punctuation'),
#   ('방탄소년단', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('Dreamers', 'Alpha'),
#   ('[', 'Punctuation'),
#   ('Music', 'Alpha'),
#   ('from', 'Alpha'),
#   ('the', 'Alpha'),
#   ('FIFA', 'Alpha'),
#   ('World', 'Alpha'),
#   ('Cup', 'Alpha'),
#   ('Qatar', 'Alpha'),
#   ('2022', 'Number'),
#   ('Official', 'Alpha'),
#   ('Soundtrack', 'Alpha'),
#   (']', 'Punctuation'),
#   ('(', 'Punctuation'),
#   ('Feat', 'Alpha'),
#   ('.', 'Punctuation'),
#   ('FIFA', 'Alpha'),
#   ('Sound', 'Alpha'),
#   (')', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('BIG', 'Alpha'),
#   ('Naughty', 'Alpha'),
#   ('(', 'Punctuation'),
#   ('서동현', 'Noun'),
#   (')', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('사랑', 'Noun'),
#   ('이라', 'Josa'),
#   ('믿었던', 'Verb'),
#   ('것', 'Noun'),
#   ('들', 'Suffix'),
#   ('은', 'Josa'),
#   ('(', 'Punctuation'),
#   ('Feat', 'Alpha'),
#   ('.', 'Punctuation'),
#   ('이수현', 'Noun'),
#   (')', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('테이', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('Monologue', 'Alpha')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('방탄소년단', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('Butter', 'Alpha')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('Charlie', 'Alpha'),
#   ('Puth', 'Alpha'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('That', 'Alpha'),
#   ("'", 'Punctuation'),
#   ('s', 'Alpha'),
#   ('Hilarious', 'Alpha')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('지민', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('Alone', 'Alpha')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('우디', 'Noun'),
#   ('(', 'Punctuation'),
#   ('Woody', 'Alpha'),
#   (')', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('Say', 'Alpha'),
#   ('I', 'Alpha'),
#   ('Love', 'Alpha'),
#   ('You', 'Alpha')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('#안녕', 'Hashtag'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('해', 'Noun'),
#   ('요', 'Josa'),
#   ('(', 'Punctuation'),
#   ('2022', 'Number'),
#   (')', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('지코', 'Noun'),
#   ('(', 'Punctuation'),
#   ('ZICO', 'Alpha'),
#   (')', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('새', 'Modifier'),
#   ('삥', 'Noun'),
#   ('(', 'Punctuation'),
#   ('Prod', 'Alpha'),
#   ('.', 'Punctuation'),
#   ('ZICO', 'Alpha'),
#   (')', 'Punctuation'),
#   ('(', 'Punctuation'),
#   ('Feat', 'Alpha'),
#   ('.', 'Punctuation'),
#   ('호미', 'Noun'),
#   ('들', 'Suffix'),
#   (')', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('Anne', 'Alpha'),
#   ('-', 'Punctuation'),
#   ('Marie', 'Alpha'),
#   (',', 'Punctuation'),
#   ('민니', 'Noun'),
#   ('((', 'Punctuation'),
#   ('여자', 'Noun'),
#   (')', 'Punctuation'),
#   ('아이', 'Noun'),
#   ('들', 'Suffix'),
#   ('),', 'Punctuation'),
#   ('(', 'Punctuation'),
#   ('여자', 'Noun'),
#   (')', 'Punctuation'),
#   ('아이', 'Noun'),
#   ('들', 'Suffix'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('Expectations', 'Alpha')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('싸이', 'Noun'),
#   ('(', 'Punctuation'),
#   ('PSY', 'Alpha'),
#   (')', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('That', 'Alpha'),
#   ('That', 'Alpha'),
#   ('(', 'Punctuation'),
#   ('prod', 'Alpha'),
#   ('.', 'Punctuation'),
#   ('&', 'Punctuation'),
#   ('feat', 'Alpha'),
#   ('.', 'Punctuation'),
#   ('SUGA', 'Alpha'),
#   ('of', 'Alpha'),
#   ('BTS', 'Alpha'),
#   (')', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('NewJeans', 'Alpha'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('Cookie', 'Alpha')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('김민석', 'Noun'),
#   ('(', 'Punctuation'),
#   ('멜', 'Verb'),
#   ('로망스', 'Noun'),
#   (')', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('취중', 'Noun'),
#   ('고백', 'Noun')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('Sam', 'Alpha'),
#   ('Smith', 'Alpha'),
#   (',', 'Punctuation'),
#   ('Kim', 'Alpha'),
#   ('Petras', 'Alpha'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('Unholy', 'Alpha')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('The', 'Alpha'),
#   ('Kid', 'Alpha'),
#   ('LAROI', 'Alpha'),
#   (',', 'Punctuation'),
#   ('Justin', 'Alpha'),
#   ('Bieber', 'Alpha'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('STAY', 'Alpha')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('방탄소년단', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('Permission', 'Alpha'),
#   ('to', 'Alpha'),
#   ('Dance', 'Alpha')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('BLACKPINK', 'Alpha'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('Shut', 'Alpha'),
#   ('Down', 'Alpha')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('김민석', 'Noun'),
#   ('(', 'Punctuation'),
#   ('멜', 'Verb'),
#   ('로망스', 'Noun'),
#   (')', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('너', 'Noun'),
#   ('와', 'Josa'),
#   ('함께', 'Adverb')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('주호', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('내', 'Noun'),
#   ('가', 'Josa'),
#   ('아니라도', 'Adjective')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('WSG', 'Alpha'),
#   ('워', 'Noun'),
#   ('너비', 'Noun'),
#   ('(', 'Punctuation'),
#   ('가야', 'Noun'),
#   ('G', 'Alpha'),
#   (')', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('그때', 'Noun'),
#   ('그', 'Noun'),
#   ('순간', 'Noun'),
#   ('그대로', 'Noun'),
#   ('(', 'Punctuation'),
#   ('그', 'Determiner'),
#   ('그', 'Modifier'),
#   ('그', 'Noun'),
#   (')', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('(', 'Punctuation'),
#   ('여자', 'Noun'),
#   (')', 'Punctuation'),
#   ('아이', 'Noun'),
#   ('들', 'Suffix'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('TOMBOY', 'Alpha')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('먼데이', 'Noun'),
#   ('키즈', 'Noun'),
#   ('(', 'Punctuation'),
#   ('Monday', 'Alpha'),
#   ('Kiz', 'Alpha'),
#   (')', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('되돌리다', 'Verb')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('10', 'Number'),
#   ('CM', 'Alpha'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('그라데이션', 'Noun')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('STAYC', 'Alpha'),
#   ('(', 'Punctuation'),
#   ('스테이', 'Noun'),
#   ('씨', 'Suffix'),
#   (')', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('Poppy', 'Alpha'),
#   ('(', 'Punctuation'),
#   ('Korean', 'Alpha'),
#   ('Ver', 'Alpha'),
#   ('.)', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('투모로우', 'Noun'),
#   ('바이', 'Noun'),
#   ('투게더', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('Sugar', 'Alpha'),
#   ('Rush', 'Alpha'),
#   ('Ride', 'Alpha')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('김호중', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('그', 'Determiner'),
#   ('중', 'Noun'),
#   ('에', 'Josa'),
#   ('그대', 'Noun'),
#   ('를', 'Josa'),
#   ('만나', 'Verb')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('경', 'Modifier'),
#   ('서예지', 'Noun'),
#   (',', 'Punctuation'),
#   ('전', 'Modifier'),
#   ('건호', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('다정히', 'Adjective'),
#   ('내', 'Noun'),
#   ('이름', 'Noun'),
#   ('을', 'Josa'),
#   ('부르면', 'Verb')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('LE', 'Alpha'),
#   ('SSERAFIM', 'Alpha'),
#   ('(', 'Punctuation'),
#   ('르', 'Noun'),
#   ('세라핌', 'Noun'),
#   (')', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('FEARLESS', 'Alpha')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('IVE', 'Alpha'),
#   ('(', 'Punctuation'),
#   ('아이브', 'Noun'),
#   (')', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('ELEVEN', 'Alpha')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('BLACKPINK', 'Alpha'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('Pink', 'Alpha'),
#   ('Venom', 'Alpha')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('BIG', 'Alpha'),
#   ('Naughty', 'Alpha'),
#   ('(', 'Punctuation'),
#   ('서동현', 'Noun'),
#   (')', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('정이', 'Noun'),
#   ('라고', 'Josa'),
#   ('하자', 'Noun'),
#   ('(', 'Punctuation'),
#   ('Feat', 'Alpha'),
#   ('.', 'Punctuation'),
#   ('10', 'Number'),
#   ('CM', 'Alpha'),
#   (')', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('Crush', 'Alpha'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('Rush', 'Alpha'),
#   ('Hour', 'Alpha'),
#   ('(', 'Punctuation'),
#   ('Feat', 'Alpha'),
#   ('.', 'Punctuation'),
#   ('j', 'Alpha'),
#   ('-', 'Punctuation'),
#   ('hope', 'Alpha'),
#   ('of', 'Alpha'),
#   ('BTS', 'Alpha'),
#   (')', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('이영지', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('NOT', 'Alpha'),
#   ('SORRY', 'Alpha'),
#   ('(', 'Punctuation'),
#   ('Feat', 'Alpha'),
#   ('.', 'Punctuation'),
#   ('pH', 'Alpha'),
#   ('-', 'Punctuation'),
#   ('1', 'Number'),
#   (')', 'Punctuation'),
#   ('(', 'Punctuation'),
#   ('Prod', 'Alpha'),
#   ('.', 'Punctuation'),
#   ('by', 'Alpha'),
#   ('Slom', 'Alpha'),
#   (')', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('윤하', 'Noun'),
#   ('(', 'Punctuation'),
#   ('YOUNHA', 'Alpha'),
#   (')', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('오르트구름', 'Noun')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('김호중', 'Noun'),
#   (',', 'Punctuation'),
#   ('송가', 'Noun'),
#   ('인', 'Josa'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('당신', 'Noun'),
#   ('을', 'Josa'),
#   ('만나', 'Verb')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('이홍기', 'Noun'),
#   ('(', 'Punctuation'),
#   ('FT', 'Alpha'),
#   ('아일랜드', 'Noun'),
#   (')', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('아', 'Exclamation'),
#   ('모르', 'Verb'),
#   ('파티', 'Noun')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('폴킴', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('모든', 'Noun'),
#   ('날', 'Noun'),
#   (',', 'Punctuation'),
#   ('모든', 'Noun'),
#   ('순간', 'Noun'),
#   ('(', 'Punctuation'),
#   ('Every', 'Alpha'),
#   ('day', 'Alpha'),
#   (',', 'Punctuation'),
#   ('Every', 'Alpha'),
#   ('Moment', 'Alpha'),
#   (')', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('송하예', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('그대', 'Noun'),
#   ('를', 'Josa'),
#   ('알', 'Noun'),
#   ('고', 'Josa')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('임창정', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('그대', 'Noun'),
#   ('라는', 'Josa'),
#   ('사치', 'Noun')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('NMIXX', 'Alpha'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('Young', 'Alpha'),
#   (',', 'Punctuation'),
#   ('Dumb', 'Alpha'),
#   (',', 'Punctuation'),
#   ('Stupid', 'Alpha')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('신예', 'Noun'),
#   ('영', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('마지막', 'Noun'),
#   ('사랑', 'Noun')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('김호중', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('나', 'Noun'),
#   ('의', 'Josa'),
#   ('목소리', 'Noun'),
#   ('로', 'Josa')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('주호', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('잘가요', 'Verb')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('경서', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('나', 'Noun'),
#   ('의', 'Josa'),
#   ('X', 'Alpha'),
#   ('에게', 'Josa')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('방탄소년단', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('Yet', 'Alpha'),
#   ('To', 'Alpha'),
#   ('Come', 'Alpha')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('10', 'Number'),
#   ('CM', 'Alpha'),
#   (',', 'Punctuation'),
#   ('BIG', 'Alpha'),
#   ('Naughty', 'Alpha'),
#   ('(', 'Punctuation'),
#   ('서동현', 'Noun'),
#   (')', 'Punctuation'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('딱', 'Adverb'),
#   ('10', 'Number'),
#   ('CM', 'Alpha'),
#   ('만', 'Noun')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('HIGH', 'Alpha'),
#   ('4', 'Number'),
#   ('(', 'Punctuation'),
#   ('하이포', 'Noun'),
#   ('),', 'Punctuation'),
#   ('아이유', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('봄', 'Noun'),
#   ('사랑', 'Noun'),
#   ('벚꽃', 'Noun'),
#   ('말고', 'Josa')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('신예', 'Noun'),
#   ('영', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('네', 'Noun'),
#   ('가', 'Josa'),
#   ('보고', 'Noun'),
#   ('싶은', 'Verb'),
#   ('건', 'Noun'),
#   ('자연스러운', 'Adjective'),
#   ('거', 'Noun'),
#   ('겠지', 'Verb')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('최유리', 'Noun'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('그', 'Noun'),
#   ('댄', 'Verb'),
#   ('행복', 'Noun'),
#   ('에', 'Josa'),
#   ('살텐데', 'Verb'),
#   ('(', 'Punctuation'),
#   ('2022', 'Number'),
#   (')', 'Punctuation')],
#  [('■', 'Foreign'),
#   ('제목', 'Noun'),
#   (':', 'Punctuation'),
#   ('Justin', 'Alpha'),
#   ('Bieber', 'Alpha'),
#   ('■', 'Foreign'),
#   ('내용', 'Noun'),
#   (':', 'Punctuation'),
#   ('Off', 'Alpha'),
#   ('My', 'Alpha'),
#   ('Face', 'Alpha')]]

# %%
okt_pos_result =[ ]

#바깥쪽 리스트 okt_pos에서 안쪽 리스트 pos에 해당하는 100개의 리스트를 반복
for pos in okt_pos : 
    for i in pos :   #안쪽 리스트 pos에서 각각의 튜플 i를 반복
        okt_pos_result.append(i)  #(튜플) i 값을 추가하는 리스트 pos_result

# %%
print(okt_pos_result) #하나의 리스트 안에 튜플들이 있는 구조
# Out:
# [('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('IVE', 'Alpha'), ('(', 'Punctuation'), ('아이브', 'Noun'), (')', 'Punctuation'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('Kitsch', 'Alpha'), ('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('NewJeans', 'Alpha'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('Ditto', 'Alpha'), ('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('NewJeans', 'Alpha'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('OMG', 'Alpha'), ('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('NewJeans', 'Alpha'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('Hype', 'Alpha'), ('boy', 'Alpha'), ('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('STAYC', 'Alpha'), ('(', 'Punctuation'), ('스테이', 'Noun'), ('씨', 'Suffix'), (')', 'Punctuation'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('Teddy', 'Alpha'), ('Bear', 'Alpha'), ('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('우디', 'Noun'), ('(', 'Punctuation'), ('Woody', 'Alpha'), (')', 'Punctuation'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('Nostalgia', 'Alpha'), ('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('윤하', 'Noun'), ('(', 'Punctuation'), ('YOUNHA', 'Alpha'), (')', 'Punctuation'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('사건', 'Noun'), ('의', 'Josa'), ('지평선', 'Noun'), ('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('임영웅', 'Noun'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('사랑', 'Noun'), ('은', 'Josa'), ('늘', 'Noun'), ('도망가', 'Verb'), ('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('부석', 'Noun'), ('순', 'Noun'), ('(', 'Punctuation'), ('SEVENTEEN', 'Alpha'), (')', 'Punctuation'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('파이팅', 'Noun'), ('해야지', 'Verb'), ('(', 'Punctuation'), ('Feat', 'Alpha'), ('.', 'Punctuation'), ('이영지', 'Noun'), (')', 'Punctuation'), ('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('Zior', 'Alpha'), ('Park', 'Alpha'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('CHRISTIAN', 'Alpha'), ('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('DK', 'Alpha'), ('(', 'Punctuation'), ('디셈버', 'Noun'), (')', 'Punctuation'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('심', 'Noun'), ('(', 'Punctuation'), ('心', 'Foreign'), (')', 'Punctuation'), ('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('지민', 'Noun'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('Like', 'Alpha'), ('Crazy', 'Alpha'), ('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('Charlie', 'Alpha'), ('Puth', 'Alpha'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('I', 'Alpha'), ('Don', 'Alpha'), ("'", 'Punctuation'), ('t', 'Alpha'), ('Think', 'Alpha'), ('That', 'Alpha'), ('I', 'Alpha'), ('Like', 'Alpha'), ('Her', 'Alpha'), ('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('임영웅', 'Noun'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('우리', 'Noun'), ('들', 'Suffix'), ('의', 'Josa'), ('블루스', 'Noun'), ('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('지아', 'Noun'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('사랑', 'Noun'), ('하기', 'Verb'), ('싫어', 'Adjective'), ('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('포맨', 'Noun'), ('(', 'Punctuation'), ('4', 'Number'), ('MEN', 'Alpha'), (')', 'Punctuation'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('나비', 'Noun'), ('무덤', 'Noun'), ('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('임영웅', 'Noun'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('다시', 'Noun'), ('만날', 'Noun'), ('수', 'Noun'), ('있을까', 'Adjective'), ('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('임영웅', 'Noun'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('London', 'Alpha'), ('Boy', 'Alpha'), ('■', 'Foreign'), ('제목', 'Noun'), (':', 'Punctuation'), ('임영웅', 'Noun'), ('■', 'Foreign'), ('내용', 'Noun'), (':', 'Punctuation'), ('Polaroid', 'Alpha'), ('■', ...

# %%
print('● 데이터 타입 : ', type(okt_pos_result)) 
print('● shape : ', np.shape(okt_pos_result))
print("● 리스트에 있는 튜플 개수 : ", len(okt_pos_result))
# Out:
# ● 데이터 타입 :  <class 'list'>
# ● shape :  (1262, 2)
# ● 리스트에 있는 튜플 개수 :  1262

# %% [markdown]
# <span style="color: red ; font-size: 14pt">
# 3.2. nouns() 함수를 이용한 명사 추출하기
# </span>

# %%
okt_nouns=[]  #명사 부분 저장을 위한 리스트

for data in data_tit_con : 
    #명사 부분 리스트에 추가 
    #okt.nouns()는 리스트 안에 '스트링'을 넣어서 리턴
    #okt_nouns는 리스트이고,okt.nouns() 결과도 리스트이므로 2차원리스트 생성 
    
    okt_nouns.append(okt.nouns(data))

# %%
#바깥쪽 리스트 안에 또 하나의 리스트가 포함되어 있으며
#내부 리스트 안에 튜플이 있는 구조

print(okt_nouns)
# Out:
# [['제목', '아이브', '내용'], ['제목', '내용'], ['제목', '내용'], ['제목', '내용'], ['제목', '스테이', '내용'], ['제목', '우디', '내용'], ['제목', '윤하', '내용', '사건', '지평선'], ['제목', '임영웅', '내용', '사랑', '늘'], ['제목', '부석', '순', '내용', '파이팅', '이영지'], ['제목', '내용'], ['제목', '디셈버', '내용', '심'], ['제목', '지민', '내용'], ['제목', '내용'], ['제목', '임영웅', '내용', '우리', '블루스'], ['제목', '지아', '내용', '사랑'], ['제목', '포맨', '내용', '나비', '무덤'], ['제목', '임영웅', '내용', '다시', '만날', '수'], ['제목', '임영웅', '내용'], ['제목', '임영웅', '내용'], ['제목', '내용'], ['제목', '임영웅', '내용', '무지개'], ['제목', '임영웅', '내용', '이제', '나'], ['제목', '내용'], ['제목', '임영웅', '내용', '아버지'], ['제목', '아이브', '내용'], ['제목', '주주', '시크릿', '내용', '밤'], ['제목', '르', '세라핌', '내용'], ['제목', '임영웅', '내용'], ['제목', '임영웅', '내용', '인생', '찬가'], ['제목', '지민', '내용'], ['제목', '임영웅', '내용', '손', '그대'], ['제목', '임영웅', '내용', '사랑', '진짜'], ['제목', '임영웅', '내용', '연애편지'], ['제목', '아이브', '내용'], ['제목', '임영웅', '내용', '보금자리'], ['제목', '내용'], ['제목', '태양', '내용'], ['제목', '로망스', '내용', '사랑'], ['제목', '송하예', '내용', '너', '하루'], ['제목', '내용'], ['제목', '워', '너비', '가야', '내용', '너'], ['제목', '하이', '키', '내용', '건물', '사이', '피어', '장미'], ['제목', '내용'], ['제목', '방탄소년단', '내용'], ['제목', '성시경', '내용', '너', '모든', '순간'], ['제목', '방탄소년단', '내용', '봄날'], ['제목', '내용'], ['제목', '지민', '내용'], ['제목', '정', '효빈', '내용', '혼자', '나'], ['제목', '여자', '아이', '내용'], ['제목', '정국', '방탄소년단', '내용'], ['제목', '서동현', '내용', '사랑', '것', '이수현'], ['제목', '테이', '내용'], ['제목', '방탄소년단', '내용'], ['제목', '내용'], ['제목', '지민', '내용'], ['제목', '우디', '내용'], ['제목', '내용', '해'], ['제목', '지코', '내용', '삥', '호미'], ['제목', '민니', '여자', '아이', '여자', '아이', '내용'], ['제목', '싸이', '내용'], ['제목', '내용'], ['제목', '김민석', '로망스', '내용', '취중', '고백'], ['제목', '내용'], ['제목', '내용'], ['제목', '방탄소년단', '내용'], ['제목', '내용'], ['제목', '김민석', '로망스', '내용', '너'], ['제목', '주호', '내용', '내'], ['제목', '워', '너비', '가야', '내용', '그때', '그', '순간', '그대로', '그'], ['제목', '여자', '아이', '내용'], ['제목', '먼데이', '키즈', '내용'], ['제목', '내용', '그라데이션'], ['제목', '스테이', '내용'], ['제목', '투모로우', '바이', '투게더', '내용'], ['제목', '김호중', '내용', '중', '그대'], ['제목', '서예지', '건호', '내용', '내', '이름'], ['제목', '르', '세라핌', '내용'], ['제목', '아이브', '내용'], ['제목', '내용'], ['제목', '서동현', '내용', '정이', '하자'], ['제목', '내용'], ['제목', '이영지', '내용'], ['제목', '윤하', '내용', '오르트구름'], ['제목', '김호중', '송가', '내용', '당신'], ['제목', '이홍기', '아일랜드', '내용', '파티'], ['제목', '폴킴', '내용', '모든', '날', '모든', '순간'], ['제목', '송하예', '내용', '그대', '알'], ['제목', '임창정', '내용', '그대', '사치'], ['제목', '내용'], ['제목', '신예', '영', '내용', '마지막', '사랑'], ['제목', '김호중', '내용', '나', '목소리'], ['제목', '주호', '내용'], ['제목', '경서', '내용', '나'], ['제목', '방탄소년단', '내용'], ['제목', '서동현', '내용', '만'], ['제목', '하이포', '아이유', '내용', '봄', '사랑', '벚꽃'], ['제목', '신예', '영', '내용', '네', '보고', '건', '거'], ['제목', '최유리', '내용', '그', '행복'], ['제목', '내용']]

# %%
print('● 데이터 타입 : ', type(okt_nouns)) 
print("● ['스트링', ...'스트링'] 리스트 개수 : ", len(okt_nouns) )
# Out:
# ● 데이터 타입 :  <class 'list'>
# ● ['스트링', ...'스트링'] 리스트 개수 :  100

# %%
okt_nouns_result =[ ]

#바깥쪽 리스트 okt_nouns에서 안쪽 리스트 nouns에 해당하는 100개의 리스트를 반복
for nouns in okt_nouns : 
    for i in nouns :   #안쪽 리스트 nouns에서 각각의 '스트링' i를 반복
        okt_nouns_result.append(i)  #'스트링' i 값을 추가하는 리스트 nouns_result

# %%
print(okt_nouns_result) #하나의 리스트 안에 '스트링'이 있는 구조
# Out:
# ['제목', '아이브', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '스테이', '내용', '제목', '우디', '내용', '제목', '윤하', '내용', '사건', '지평선', '제목', '임영웅', '내용', '사랑', '늘', '제목', '부석', '순', '내용', '파이팅', '이영지', '제목', '내용', '제목', '디셈버', '내용', '심', '제목', '지민', '내용', '제목', '내용', '제목', '임영웅', '내용', '우리', '블루스', '제목', '지아', '내용', '사랑', '제목', '포맨', '내용', '나비', '무덤', '제목', '임영웅', '내용', '다시', '만날', '수', '제목', '임영웅', '내용', '제목', '임영웅', '내용', '제목', '내용', '제목', '임영웅', '내용', '무지개', '제목', '임영웅', '내용', '이제', '나', '제목', '내용', '제목', '임영웅', '내용', '아버지', '제목', '아이브', '내용', '제목', '주주', '시크릿', '내용', '밤', '제목', '르', '세라핌', '내용', '제목', '임영웅', '내용', '제목', '임영웅', '내용', '인생', '찬가', '제목', '지민', '내용', '제목', '임영웅', '내용', '손', '그대', '제목', '임영웅', '내용', '사랑', '진짜', '제목', '임영웅', '내용', '연애편지', '제목', '아이브', '내용', '제목', '임영웅', '내용', '보금자리', '제목', '내용', '제목', '태양', '내용', '제목', '로망스', '내용', '사랑', '제목', '송하예', '내용', '너', '하루', '제목', '내용', '제목', '워', '너비', '가야', '내용', '너', '제목', '하이', '키', '내용', '건물', '사이', '피어', '장미', '제목', '내용', '제목', '방탄소년단', '내용', '제목', '성시경', '내용', '너', '모든', '순간', '제목', '방탄소년단', '내용', '봄날', '제목', '내용', '제목', '지민', '내용', '제목', '정', '효빈', '내용', '혼자', '나', '제목', '여자', '아이', '내용', '제목', '정국', '방탄소년단', '내용', '제목', '서동현', '내용', '사랑', '것', '이수현', '제목', '테이', '내용', '제목', '방탄소년단', '내용', '제목', '내용', '제목', '지민', '내용', '제목', '우디', '내용', '제목', '내용', '해', '제목', '지코', '내용', '삥', '호미', '제목', '민니', '여자', '아이', '여자', '아이', '내용', '제목', '싸이', '내용', '제목', '내용', '제목', '김민석', '로망스', '내용', '취중', '고백', '제목', '내용', '제목', '내용', '제목', '방탄소년단', '내용', '제목', '내용', '제목', '김민석', '로망스', '내용', '너', '제목', '주호', '내용', '내', '제목', '워', '너비', '가야', '내용', '그때', '그', '순간', '그대로', '그', '제목', '여자', '아이', '내용', '제목', '먼데이', '키즈', '내용', '제목', '내용', '그라데이션', '제목', '스테이', '내용', '제목', '투모로우', '바이', '투게더', '내용', '제목', '김호중', '내용', '중', '그대', '제목', '서예지', '건호', '내용', '내', '이름', '제목', '르', '세라핌', '내용', '제목', '아이브', '내용', '제목', '내용', '제목', '서동현', '내용', '정이', '하자', '제목', '내용', '제목', '이영지', '내용', '제목', '윤하', '내용', '오르트구름', '제목', '김호중', '송가', '내용', '당신', '제목', '이홍기', '아일랜드', '내용', '파티', '제목', '폴킴', '내용', '모든', '날', '모든', '순간', '제목', '송하예', '내용', '그대', '알', '제목', '임창정', '내용', '그대', '사치', '제목', '내용', '제목', '신예', '영', '내용', '마지막', '사랑', '제목', '김호중', '내용', '나', '목소리', '제목', '주호', '내용', '제목', '경서', '내용', '나', '제목', '방탄소년단', '내용', '제목', '서동현', '내용', '만', '제목', '하이포', '아이유', '내용', '봄', '사랑', '벚꽃', '제목', '신예', '영', '내용', '네', '보고', '건', '거', '제목', '최유리', '내용', '그', '행복', '제목', '내용']

# %%
print('● 데이터 타입 : ', type(okt_nouns_result)) 
print('● shape : ', np.shape(okt_nouns_result))
print("● 리스트에 있는 튜플 개수 : ", len(okt_nouns_result))
# Out:
# ● 데이터 타입 :  <class 'list'>
# ● shape :  (396,)
# ● 리스트에 있는 튜플 개수 :  396

# %% [markdown]
# <span style="color: red; font-size: 18pt">
# 4. 명사의 빈도수 출력하기
# </span>

# %% [markdown]
# <span style="color: blue; font-size: 14pt">
# okt.nouns()를 대상으로 Counter()로 명사 빈도수 출력하기
# </span>

# %% [markdown]
# <span style="color: blue">
# ● collections 모듈에서 제공되는 Counter 함수를 사용하여 명사의 빈도수를 출력
# </span>

# %%
from collections import Counter

# %%
#print(okt_nouns_result) #준비된 명사 리스트 확인
print("명사 개수 : ", len(okt_nouns_result))
# Out:
# 명사 개수 :  396

# %%
#Counter는 from collections import Counter에서 제공되는 함수

okt_nouns_count = Counter(okt_nouns_result)  

print('● 데이터 타입 : ',type(okt_nouns_count))
print('● {명사 : 개수} ',okt_nouns_count)
# Out:
# ● 데이터 타입 :  <class 'collections.Counter'>
# ● {명사 : 개수}  Counter({'제목': 100, '내용': 100, '임영웅': 14, '사랑': 7, '방탄소년단': 6, '아이브': 4, '지민': 4, '나': 4, '그대': 4, '너': 4, '여자': 4, '아이': 4, '로망스': 3, '모든': 3, '순간': 3, '서동현': 3, '그': 3, '김호중': 3, '스테이': 2, '우디': 2, '윤하': 2, '이영지': 2, '르': 2, '세라핌': 2, '송하예': 2, '워': 2, '너비': 2, '가야': 2, '김민석': 2, '주호': 2, '내': 2, '신예': 2, '영': 2, '사건': 1, '지평선': 1, '늘': 1, '부석': 1, '순': 1, '파이팅': 1, '디셈버': 1, '심': 1, '우리': 1, '블루스': 1, '지아': 1, '포맨': 1, '나비': 1, '무덤': 1, '다시': 1, '만날': 1, '수': 1, '무지개': 1, '이제': 1, '아버지': 1, '주주': 1, '시크릿': 1, '밤': 1, '인생': 1, '찬가': 1, '손': 1, '진짜': 1, '연애편지': 1, '보금자리': 1, '태양': 1, '하루': 1, '하이': 1, '키': 1, '건물': 1, '사이': 1, '피어': 1, '장미': 1, '성시경': 1, '봄날': 1, '정': 1, '효빈': 1, '혼자': 1, '정국': 1, '것': 1, '이수현': 1, '테이': 1, '해': 1, '지코': 1, '삥': 1, '호미': 1, '민니': 1, '싸이': 1, '취중': 1, '고백': 1, '그때': 1, '그대로': 1, '먼데이': 1, '키즈': 1, '그라데이션': 1, '투모로우': 1, '바이': 1, '투게더': 1, '중': 1, '서예지': 1, '건호': 1, '이름': 1, '정이': 1, '하자': 1, '오르트구름': 1, '송가': 1, '당신': 1, '이홍기': 1, '아일랜드': 1, '파티': 1, '폴킴': 1, '날': 1, '알': 1, '임창정': 1, '사치': 1, '마지막': 1, '목소리': 1, '경서': 1, '만': 1, '하이포': 1, '아이유': 1, '봄': 1, '벚꽃': 1, '네': 1, '보고': 1, '건': 1, '거': 1, '최유리': 1, '행복': 1})

# %% [markdown]
# <span style="color: red; font-size: 18pt">
# 5. 불용어 사전을 이용한 불필요한 명사 제거하기
# </span>

# %% [markdown]
# <span style="color: blue; font-size: 14pt">
# 불용어 사전을 read()로 읽기 (return type : string)
# </span>

# %%
stop_word = open("C:/Users/Mac001/DataSci/불용어사전.txt", encoding='utf-8').read()
print('● 불용어 사전 데이터 타입 : ',type(stop_word))
print('● 불용어 사전 내용 ')  
print(stop_word)  #print()를 사용하면 '\n'이 출력되지 않는다.
# Out:
# ● 불용어 사전 데이터 타입 :  <class 'str'>
# ● 불용어 사전 내용
# 자연어
# 처리
# 제목
# 내용

# %% [markdown]
# <span style="color: blue; font-size: 14pt">
# 불용어 사전을 기반으로 저장된 명사 데이터셋에서 불용어 제거하기
# </span>

# %% [markdown]
# <span style="color:green">
# ● 파이썬 문법 참고 <br>
# </span>

# %%
#파이썬 문법 참고
#0 에서 9까지 1씩 증가하면서
#x를 2로 나누어서 나머지가 0 인 경우.. 
#즉 짝수인 경우 x만 M에 할당하는 코드 

M = [x for x in range(10) if x % 2 == 0]
print(M)
# Out:
# [0, 2, 4, 6, 8]

# %%
#print("● okt.nouns()를 활용하여 추출된 명사 : %d 개" %len(okt_nouns))
#print(okt_nouns,'\n')

# %%
stop_okt = [ i for i in okt_nouns_result if i in stop_word ] 
          #i가 stop_word에 있으면 i를 stop_okt에 할당한다. 
          #stop_word는 \n 단위로 비교된다.
print("● 추출된 명사가 불용어에 해당되는 명사 : %d 개" %len(stop_okt))
print(stop_okt,'\n')
# Out:
# ● 추출된 명사가 불용어에 해당되는 명사 : 202 개
# ['제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '내', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '내', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용', '제목', '내용']

# %%
non_stop_okt = [ j for j in okt_nouns_result if j not in stop_word ] 
         #j가 stop_word(불용어)에 없으면 j를 non_stop_okt에 할당한다. 
         #stop_word는 \n 단위로 비교된다.
print("● 추출된 명사가 불용어에 해당되지 않는 명사 : %d 개" %len(non_stop_okt))
print(non_stop_okt)
# Out:
# ● 추출된 명사가 불용어에 해당되지 않는 명사 : 194 개
# ['아이브', '스테이', '우디', '윤하', '사건', '지평선', '임영웅', '사랑', '늘', '부석', '순', '파이팅', '이영지', '디셈버', '심', '지민', '임영웅', '우리', '블루스', '지아', '사랑', '포맨', '나비', '무덤', '임영웅', '다시', '만날', '수', '임영웅', '임영웅', '임영웅', '무지개', '임영웅', '이제', '나', '임영웅', '아버지', '아이브', '주주', '시크릿', '밤', '르', '세라핌', '임영웅', '임영웅', '인생', '찬가', '지민', '임영웅', '손', '그대', '임영웅', '사랑', '진짜', '임영웅', '연애편지', '아이브', '임영웅', '보금자리', '태양', '로망스', '사랑', '송하예', '너', '하루', '워', '너비', '가야', '너', '하이', '키', '건물', '사이', '피어', '장미', '방탄소년단', '성시경', '너', '모든', '순간', '방탄소년단', '봄날', '지민', '정', '효빈', '혼자', '나', '여자', '아이', '정국', '방탄소년단', '서동현', '사랑', '것', '이수현', '테이', '방탄소년단', '지민', '우디', '해', '지코', '삥', '호미', '민니', '여자', '아이', '여자', '아이', '싸이', '김민석', '로망스', '취중', '고백', '방탄소년단', '김민석', '로망스', '너', '주호', '워', '너비', '가야', '그때', '그', '순간', '그대로', '그', '여자', '아이', '먼데이', '키즈', '그라데이션', '스테이', '투모로우', '바이', '투게더', '김호중', '중', '그대', '서예지', '건호', '이름', '르', '세라핌', '아이브', '서동현', '정이', '하자', '이영지', '윤하', '오르트구름', '김호중', '송가', '당신', '이홍기', '아일랜드', '파티', '폴킴', '모든', '날', '모든', '순간', '송하예', '그대', '알', '임창정', '그대', '사치', '신예', '영', '마지막', '사랑', '김호중', '나', '목소리', '주호', '경서', '나', '방탄소년단', '서동현', '만', '하이포', '아이유', '봄', '사랑', '벚꽃', '신예', '영', '네', '보고', '건', '거', '최유리', '그', '행복']

# %% [markdown]
# <span style="color: red; font-size: 18pt">
# 6. 글자 수 제한으로 불용어 제거 추가하기
# </span>

# %% [markdown]
# <span style="color: blue; font-size: 14pt">
# 불용어 사전을 통과한 okt.nouns()를 대상으로 글자 수 제한으로 불용어 제거하기
# </span>

# %%
print("● 불용어 사전을 통과한 명사 개수 : %d 개" %len(non_stop_okt))
print("● 불용어 사전을 통과한 명사" )
print(non_stop_okt)
# Out:
# ● 불용어 사전을 통과한 명사 개수 : 194 개
# ● 불용어 사전을 통과한 명사
# ['아이브', '스테이', '우디', '윤하', '사건', '지평선', '임영웅', '사랑', '늘', '부석', '순', '파이팅', '이영지', '디셈버', '심', '지민', '임영웅', '우리', '블루스', '지아', '사랑', '포맨', '나비', '무덤', '임영웅', '다시', '만날', '수', '임영웅', '임영웅', '임영웅', '무지개', '임영웅', '이제', '나', '임영웅', '아버지', '아이브', '주주', '시크릿', '밤', '르', '세라핌', '임영웅', '임영웅', '인생', '찬가', '지민', '임영웅', '손', '그대', '임영웅', '사랑', '진짜', '임영웅', '연애편지', '아이브', '임영웅', '보금자리', '태양', '로망스', '사랑', '송하예', '너', '하루', '워', '너비', '가야', '너', '하이', '키', '건물', '사이', '피어', '장미', '방탄소년단', '성시경', '너', '모든', '순간', '방탄소년단', '봄날', '지민', '정', '효빈', '혼자', '나', '여자', '아이', '정국', '방탄소년단', '서동현', '사랑', '것', '이수현', '테이', '방탄소년단', '지민', '우디', '해', '지코', '삥', '호미', '민니', '여자', '아이', '여자', '아이', '싸이', '김민석', '로망스', '취중', '고백', '방탄소년단', '김민석', '로망스', '너', '주호', '워', '너비', '가야', '그때', '그', '순간', '그대로', '그', '여자', '아이', '먼데이', '키즈', '그라데이션', '스테이', '투모로우', '바이', '투게더', '김호중', '중', '그대', '서예지', '건호', '이름', '르', '세라핌', '아이브', '서동현', '정이', '하자', '이영지', '윤하', '오르트구름', '김호중', '송가', '당신', '이홍기', '아일랜드', '파티', '폴킴', '모든', '날', '모든', '순간', '송하예', '그대', '알', '임창정', '그대', '사치', '신예', '영', '마지막', '사랑', '김호중', '나', '목소리', '주호', '경서', '나', '방탄소년단', '서동현', '만', '하이포', '아이유', '봄', '사랑', '벚꽃', '신예', '영', '네', '보고', '건', '거', '최유리', '그', '행복']

# %%
refine_non_stop_okt = []

for i in non_stop_okt :  
    #글자수가 2자 ~ 10자에 해당되는 단어만 추출
    if len(i) >= 3 and len(i) <= 10 : 
        refine_non_stop_okt.append(i) 
        
print("● 글자 수가 2~10 사이 명사 : %d 개" %len(refine_non_stop_okt))    
print(refine_non_stop_okt)
# Out:
# ● 글자 수가 2~10 사이 명사 : 69 개
# ['아이브', '스테이', '지평선', '임영웅', '파이팅', '이영지', '디셈버', '임영웅', '블루스', '임영웅', '임영웅', '임영웅', '임영웅', '무지개', '임영웅', '임영웅', '아버지', '아이브', '시크릿', '세라핌', '임영웅', '임영웅', '임영웅', '임영웅', '임영웅', '연애편지', '아이브', '임영웅', '보금자리', '로망스', '송하예', '방탄소년단', '성시경', '방탄소년단', '방탄소년단', '서동현', '이수현', '방탄소년단', '김민석', '로망스', '방탄소년단', '김민석', '로망스', '그대로', '먼데이', '그라데이션', '스테이', '투모로우', '투게더', '김호중', '서예지', '세라핌', '아이브', '서동현', '이영지', '오르트구름', '김호중', '이홍기', '아일랜드', '송하예', '임창정', '마지막', '김호중', '목소리', '방탄소년단', '서동현', '하이포', '아이유', '최유리']

# %% [markdown]
# <span style="color: red; font-size: 18pt">
# 7. 불용어가 제거된 명사를 대상으로 빈도수 다시 출력하기
# </span>

# %% [markdown]
# <span style="color: blue; font-size: 14pt">
# 불용어가 제거된 okt.nouns()를 대상으로 명사의 빈도수 출력하기
# </span>

# %%
import operator
#Counter는 from collections import Counter에서 제공되는 함수

re_okt_nouns_count = dict(Counter(refine_non_stop_okt))
# collections.Counter타입은 딕셔너리의 value를 기준으로 내림차순 정렬
print('● 데이터 타입 : ',type(re_okt_nouns_count))
print('● {명사 : 개수} ',re_okt_nouns_count)
d1 = sorted(re_okt_nouns_count.items(),key=operator.itemgetter(1),reverse=True )
d1
j = 1
a=[]
for i in d1:
    a.append(i)
    j +=1
    if j ==20:
        break
b = dict(a)
# Out:
# ● 데이터 타입 :  <class 'dict'>
# ● {명사 : 개수}  {'아이브': 4, '스테이': 2, '지평선': 1, '임영웅': 14, '파이팅': 1, '이영지': 2, '디셈버': 1, '블루스': 1, '무지개': 1, '아버지': 1, '시크릿': 1, '세라핌': 2, '연애편지': 1, '보금자리': 1, '로망스': 3, '송하예': 2, '방탄소년단': 6, '성시경': 1, '서동현': 3, '이수현': 1, '김민석': 2, '그대로': 1, '먼데이': 1, '그라데이션': 1, '투모로우': 1, '투게더': 1, '김호중': 3, '서예지': 1, '오르트구름': 1, '이홍기': 1, '아일랜드': 1, '임창정': 1, '마지막': 1, '목소리': 1, '하이포': 1, '아이유': 1, '최유리': 1}

# %% [markdown]
# <span style="color: red; font-size: 18pt">
# 8. 워드 클라우드를 활용하여 명사의 빈도수 시각화
# </span>

# %% [markdown]
# wordcloud 공식 홈페이지
# https://amueller.github.io/word_cloud/index.html

# %% [markdown]
# <span style="color: blue; font-size: 14pt">
# 불용어가 제거된 okt.nouns()를 대상으로 명사의 빈도수를 워드클라우드로 시각화하기
# </span>

# %% [markdown]
# <span style="color: blue">
# ● WordCloud( )의 generate_from_frequencies( ) 함수 input type 은 dictionary 이고, return type은 image 이다.
# </span>

# %%
from wordcloud import WordCloud  

wc = WordCloud(font_path="c:/windows/fonts/HMFMMUEX.TTC" ,  #폰트 설정
                      relative_scaling='auto',  #워드클라우드에 표현될 글자의 상대적 비율 (max:1, auto : 0.5) 
                      background_color='yellow',  #배경색                       
                     ).generate_from_frequencies(b)  #딕셔너리 데이터의 값을 기반으로 워드클라우드를 생성한다.

# %%
wc

# %%
import matplotlib.pyplot as plt 
#아래의 %matplotlib qt5 코드를 입력하면 시각화 결과가 새로운 윈도우 창에 출력됨
#%matplotlib qt5

# %%
plt.rcParams["figure.figsize"] = (14,4) #가로 너비 14인치, 세로 높이 4인치 
plt.rcParams['axes.grid'] = True   #또는 True
fig = plt.figure() #이미지 크기가 할당됨 
print("이미지 크기 : ", fig)
plt.axis('off') 
plt.imshow(wc)  #위에서 설정한 WordCcloud 옵션에 따른 이미지가 화면에 출력
# Out:
# 이미지 크기 :  Figure(1400x400)

# %%
print(fig)
# Out:
# Figure(1400x400)

# %%
plt.rcParams["figure.figsize"] = (14,4) #가로 너비 14인치, 세로 높이 4인치 
plt.rcParams['axes.grid'] = False    #또는 True

fig = plt.figure() #이미지 크기가 할당됨 
print("이미지 크기 : ", fig)

#plt.axis('on' 또는 'off') : 'on'으로 설정하면 x,y축이 출력된다. 
plt.axis('on') 
plt.imshow(wc)  #위에서 설정한 WordCcloud 옵션에 따른 이미지가 화면에 출력

#출련된 워드클라우드 이미지를 파일로 저장
fig.savefig('c:/temp/자연어처리_주요키워드.png')
# Out:
# 이미지 크기 :  Figure(1400x400)

# %% [markdown]
# <span style="color: red; font-size: 18pt">
# 9. 그래프를 활용하여 명사의 빈도수 시각화
# </span>

# %% [markdown]
# <span style="color: blue; font-size: 14pt">
# 명사의 빈도수를 그래프로 시각화하기
# </span>

# %%
#그래프 그리기 위해서 필요한 모듈 임포트하기 
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt
import matplotlib

# %%
#아래의 %matplotlib qt5 코드를 입력하면 시각화 결과가 새로운 윈도우 창에 출력됨
#%matplotlib qt5 

font_location="c:/windows/fonts/HMFMMUEX.TTC"  #한글 폰트를 셋팅함
font_name=fm.FontProperties(fname=font_location).get_name() 

#한글 깨짐을 방지하기 위해서 반드시 해야할 부분 
matplotlib.rc('font',family=font_name)

# %% [markdown]
# <span style="color:blue">
# ● nltk(Natural Language Took Kit) 모듈을 활용하여 plot 그래프를 출력 <br>
# ● plot(플롯)은 일반적으로 둘 이상의 변수 간의 관계를 나타내는 그래프로 데이터 세트를 나타내는 그래픽 기술
# </span>

# %%
from nltk.probability import FreqDist 

#FreqDist()는 딕셔너리 타입의 데이터를 셋팅해야 함
final_okt_sort_dic_graph = FreqDist(re_okt_nouns_count)

# %%
type(re_okt_nouns_count)
# Out:
# collections.Counter

# %%
type(final_okt_sort_dic_graph)
# Out:
# nltk.probability.FreqDist

# %%
print(re_okt_nouns_count)

# %%
print(final_okt_sort_dic_graph)

# %%
len(final_okt_sort_dic_graph)

# %%
plt.title('자연어 처리 주요 키워드 빈도수', fontsize=20)

final_okt_sort_dic_graph.plot(5)
plt.show()
